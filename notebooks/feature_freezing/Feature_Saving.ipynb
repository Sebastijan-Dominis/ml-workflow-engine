# %% [markdown]
# # Feature Saving

# %% [markdown]
# ## Instructions

# %% [markdown]
# - This notebook exists separately with the sole purpose of saving frozen features.
#
# - Use the correct dataset ("../data/hotel_booking_optimized.parquet")
#
# - Follow the following naming convention for the notebook's cells:
#
# 1. "##" Name of the model
# 2. "###" Version of the features
#
# - Save all of the features in the appropriate place ("../../data/features/{model_name}/{version}").
#
# - Save the schema as well.
#
# - Do NOT delete or modify the older versions.
#
# - Do NOT run any other code in this notebook.

# %%
import pandas as pd

data = pd.read_parquet("../../data/hotel_booking_optimized.parquet")

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data["hotel"].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40059
# Name: count, dtype: int64

# %%
data["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19810
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
data["customer_type"].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25123
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
data.groupby(["hotel", "customer_type"]).size().sort_values(ascending=False)
# Out:
# C:\Users\Sebastijan\AppData\Local\Temp\ipykernel_7396\3479814973.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(["hotel", "customer_type"]).size().sort_values(ascending=False)
# hotel         customer_type
# City Hotel    Transient          59404
# Resort Hotel  Transient          30209
# City Hotel    Transient-Party    17333
# Resort Hotel  Transient-Party     7790
# City Hotel    Contract            2300
# Resort Hotel  Contract            1776
# City Hotel    Group                293
# Resort Hotel  Group                284
# dtype: int64

# %% [markdown]
# ## Cancellation

# %% [markdown]
# ### Segmentation Type - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Hotel and Market Segment

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## No-show

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## Repeated Guest Prediction

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## Room Upgrade

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## ADR Tree-based

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## Lead Time Tree-based

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## Special Requests Tree-based

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ## ADR Prophet

# %% [markdown]
# ### Segment - Global

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - City Hotel

# %% [markdown]
# #### Version 1

# %% [markdown]
# ### Segment - Resort Hotel

# %% [markdown]
# #### Version 1
